# %%
import numpy as np

# %%
b=np.random.binomial(n=10,p=0.2,size=100)
b
# Out:
# array([1, 3, 1, 0, 4, 3, 2, 2, 1, 6, 2, 2, 4, 4, 2, 2, 1, 2, 2, 3, 1, 3,
#        3, 1, 2, 2, 1, 1, 3, 1, 0, 3, 1, 0, 3, 2, 1, 1, 0, 1, 1, 2, 2, 1,
#        2, 2, 4, 3, 4, 2, 3, 1, 1, 1, 3, 2, 1, 1, 4, 2, 3, 2, 1, 3, 4, 3,
#        1, 1, 3, 3, 2, 3, 3, 1, 1, 1, 3, 1, 2, 3, 2, 1, 1, 1, 2, 1, 2, 2,
#        2, 1, 1, 2, 4, 4, 2, 3, 0, 3, 4, 2], dtype=int32)

# %%
import statsmodels.api as sm
import pylab as py

# %%
sm.qqplot(b)
import matplotlib.pyplot as plt
plt.show()

# %%
sm.qqplot(b,line="45")
plt.show()

# %%
c=np.random.normal(10,5,100)
c
# Out:
# array([ 6.62104568,  6.77242417, 15.1723719 , 13.3459581 , 16.40940789,
#         8.65169958, 10.14791897,  9.65429447, 10.72570662,  5.29811148,
#        16.57805611,  6.32293207, 14.89165997, 13.20089852,  2.97286205,
#         7.50720932, 14.54576638,  9.98223845, 19.56877893,  6.15546246,
#         4.67889567,  7.65609665, 12.90004596,  8.71678761, 17.01473906,
#        15.50526565,  8.96542648,  3.28296954, 10.66572325,  3.38933564,
#         8.51327321,  8.15805011,  8.95086413, 14.84522982,  6.22419775,
#         6.42965408,  8.50866212, 24.41500335,  1.72124015,  4.87976437,
#         6.08459237,  6.24342517,  6.47759011, 10.11536134,  9.13165307,
#        11.41975788,  8.91534562,  6.64538778, 14.19368453, 20.2681893 ,
#         9.61636771, 13.03247642, 13.23643167,  8.36720159,  9.53633941,
#        16.98105434,  8.66042811, 10.66512699,  6.845706  , 11.92124781,
#        11.52968165,  8.23777327, 17.61336494, 11.63607497, 13.78037192,
#         9.09780915, 13.3944116 , 13.32702646,  6.88403924, 13.70393273,
#         6.93927547,  6.62132388,  7.61690634,  1.04852   , 12.76831887,
#         9.77384747, 15.11734849, 10.7927068 ,  8.87519055,  9.4623683 ,
#        14.37527777, 10.12674325,  5.40399085,  9.55195801, 11.47539636,
#        12.50906513, 12.89471475, 11.54341828, 18.58166789, -0.40224201,
#        12.30174557, 13.33663658, 11.56904822,  4.43420747,  5.76044949,
#         8.81052688, 11.97690343,  6.09613736, 13.47445048,  7.04796541])

# %%
sm.qqplot(c,line="45")
plt.show()
