# %%
import re

# %%
text = "My number is 9876543210"
n=re.findall(r"\d",text)
n
# Out:
# ['9', '8', '7', '6', '5', '4', '3', '2', '1', '0']

# %%
r="Im learning Data science"
m=re.search("Data science",r)
print(m)
print(m.group())
# Out:
# <re.Match object; span=(12, 24), match='Data science'>
# Data science

# %%
s="Machine learning is important machine learning tool $%^&"
d=re.sub(r"[$,%,^,&]","",s)
d
# Out:
# 'Machine learning is important machine learning tool '

# %%
t="Machine learning is important machine learning tool $%^&"
o=re.match("Machine learning",s)
o
# Out:
# <re.Match object; span=(0, 16), match='Machine learning'>

# %%
r="Hello"
p=re.sub("^Hello","",r)
p
# Out:
# ''
