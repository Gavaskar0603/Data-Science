# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# A factory produces bulbs with 10% defect rate.If 8 bulbs are selected randomly, find the probability that exactly 2 are defective.
binom.pmf(n=8,k=2,p=0.1)
# Out:
# np.float64(0.14880348000000004)

# %%
# A basketball player has a 70% success rate.He takes 6 shots.Find the probability that he scores at least 4 baskets.
c1=binom.pmf(n=6,k=4,p=0.7)
c1
# Out:
# np.float64(0.3241349999999999)

# %%
c2=binom.pmf(n=6,k=5,p=0.7)
c2
# Out:
# np.float64(0.3025259999999998)

# %%
c3=binom.pmf(n=6,k=6,p=0.7)
c3
# Out:
# np.float64(0.11764899999999996)

# %%
c1+c2+c3
# Out:
# np.float64(0.7443099999999997)

# %%
# A basketball player has a 70% success rate.He takes 6 shots.Find the probability that he scores at least 4 baskets.
binom.cdf(n=6,p=0.7,k=4)
# Out:
# np.float64(0.579825)

# %%
# In a survey, 60% of people like a product.If 5 people are selected randomly, find the probability that at most 2 people like the produ
binom.cdf(n=5,k=2,p=0.6)
# Out:
# np.float64(0.31744000000000006)
