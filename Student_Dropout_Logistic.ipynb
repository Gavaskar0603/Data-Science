# %%
import pandas as pd

d=pd.read_csv("student_dropout_dataset_v3.csv")
d
# Out:
#       Student_ID   Age  Gender  Family_Income Internet_Access  \
# 0              1  22.1    Male        25000.0             Yes
# 1              2  20.7    Male        25000.0             Yes
# 2              3  22.4    Male        40183.0             Yes
# 3              4  24.4    Male            NaN             Yes
# 4              5  20.5  Female        25319.0             Yes
# ...          ...   ...     ...            ...             ...
# 9995        9996  23.9  Female        42286.0              No
# 9996        9997  17.0  Female        61103.0             Yes
# 9997        9998  19.4    Male        25000.0             Yes
# 9998        9999  22.1  Female        40302.0             Yes
# 9999       10000  22.4  Female        76796.0             Yes
#
#       Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 0                    3.36             86.1                      2
# 1                    4.30             68.0                      2
# ...

# %%
d.isnull().sum()
# Out:
# Student_ID                 0
# Age                        0
# Gender                     0
# Family_Income            500
# Internet_Access            0
# Study_Hours_per_Day      500
# Attendance_Rate            0
# Assignment_Delay_Days      0
# Travel_Time_Minutes        0
# Part_Time_Job              0
# Scholarship                0
# Stress_Index             500
# GPA                        0
# Semester_GPA               0
# CGPA                       0
# Semester                   0
# Department                 0
# Parental_Education       511
# Dropout                    0
# dtype: int64

# %%
d["Family_Income"].mean()
# Out:
# np.float64(37945.4101)

# %%
d["Family_Income"]=d["Family_Income"].fillna(d["Family_Income"].median())
d["Family_Income"]
# Out:
# 0       25000.0
# 1       25000.0
# 2       40183.0
# 3       29740.5
# 4       25319.0
#          ...
# 9995    42286.0
# 9996    61103.0
# 9997    25000.0
# 9998    40302.0
# 9999    76796.0
# Name: Family_Income, Length: 10000, dtype: float64

# %%
d
# Out:
#       Student_ID   Age  Gender  Family_Income Internet_Access  \
# 0              1  22.1    Male        25000.0             Yes
# 1              2  20.7    Male        25000.0             Yes
# 2              3  22.4    Male        40183.0             Yes
# 3              4  24.4    Male        29740.5             Yes
# 4              5  20.5  Female        25319.0             Yes
# ...          ...   ...     ...            ...             ...
# 9995        9996  23.9  Female        42286.0              No
# 9996        9997  17.0  Female        61103.0             Yes
# 9997        9998  19.4    Male        25000.0             Yes
# 9998        9999  22.1  Female        40302.0             Yes
# 9999       10000  22.4  Female        76796.0             Yes
#
#       Study_Hours_per_Day  Attendance_Rate  Assignment_Delay_Days  \
# 0                    3.36             86.1                      2
# 1                    4.30             68.0                      2
# ...

# %%
d.isnull().sum()
# Out:
# Student_ID                 0
# Age                        0
# Gender                     0
# Family_Income              0
# Internet_Access            0
# Study_Hours_per_Day      500
# Attendance_Rate            0
# Assignment_Delay_Days      0
# Travel_Time_Minutes        0
# Part_Time_Job              0
# Scholarship                0
# Stress_Index             500
# GPA                        0
# Semester_GPA               0
# CGPA                       0
# Semester                   0
# Department                 0
# Parental_Education       511
# Dropout                    0
# dtype: int64

# %%
d["Study_Hours_per_Day"].mean()
# Out:
# np.float64(4.014591578947368)

# %%
d["Study_Hours_per_Day"]=d["Study_Hours_per_Day"].fillna(d["Study_Hours_per_Day"].median())
d["Study_Hours_per_Day"]
# Out:
# 0       3.36
# 1       4.30
# 2       4.40
# 3       4.00
# 4       4.19
#         ...
# 9995    4.62
# 9996    2.87
# 9997    4.73
# 9998    5.85
# 9999    4.95
# Name: Study_Hours_per_Day, Length: 10000, dtype: float64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             10000 non-null  int64
#  1   Age                    10000 non-null  float64
#  2   Gender                 10000 non-null  object
#  3   Family_Income          10000 non-null  float64
#  4   Internet_Access        10000 non-null  object
#  5   Study_Hours_per_Day    10000 non-null  float64
#  6   Attendance_Rate        10000 non-null  float64
#  7   Assignment_Delay_Days  10000 non-null  int64
#  8   Travel_Time_Minutes    10000 non-null  float64
#  9   Part_Time_Job          10000 non-null  object
#  10  Scholarship            10000 non-null  object
#  11  Stress_Index           9500 non-null   float64
#  12  GPA                    10000 non-null  float64
#  13  Semester_GPA           10000 non-null  float64
# ...

# %%
d["Stress_Index"].median()
# Out:
# 5.5

# %%
d["Stress_Index"]=d["Stress_Index"].fillna(d["Stress_Index"].median())
d["Stress_Index"]
# Out:
# 0       5.5
# 1       6.8
# 2       5.5
# 3       5.5
# 4       7.0
#        ...
# 9995    5.5
# 9996    6.7
# 9997    3.5
# 9998    6.2
# 9999    7.9
# Name: Stress_Index, Length: 10000, dtype: float64

# %%
d.columns[d.isnull().any()]
# Out:
# Index(['Parental_Education'], dtype='object')

# %%
d["Parental_Education"].unique()
# Out:
# array(['High School', 'Bachelor', 'Master', nan, 'PhD'], dtype=object)

# %%
nd=d.select_dtypes(include=["int64","float64"])
nd
# Out:
#       Student_ID   Age  Family_Income  Study_Hours_per_Day  Attendance_Rate  \
# 0              1  22.1        25000.0                 3.36             86.1
# 1              2  20.7        25000.0                 4.30             68.0
# 2              3  22.4        40183.0                 4.40             70.9
# 3              4  24.4        29740.5                 4.00             82.2
# 4              5  20.5        25319.0                 4.19             75.7
# ...          ...   ...            ...                  ...              ...
# 9995        9996  23.9        42286.0                 4.62             92.0
# 9996        9997  17.0        61103.0                 2.87             75.2
# 9997        9998  19.4        25000.0                 4.73             74.9
# 9998        9999  22.1        40302.0                 5.85             74.2
# 9999       10000  22.4        76796.0                 4.95             83.7
#
# ...

# %%
nd.corr()
# Out:
#                        Student_ID       Age  Family_Income  \
# Student_ID               1.000000 -0.009667       0.002087
# Age                     -0.009667  1.000000       0.008041
# Family_Income            0.002087  0.008041       1.000000
# Study_Hours_per_Day     -0.004076  0.001677       0.004086
# Attendance_Rate          0.003646  0.011307       0.003801
# Assignment_Delay_Days    0.021966  0.012405       0.007394
# Travel_Time_Minutes      0.006530 -0.014714       0.017330
# Stress_Index            -0.009885 -0.023281      -0.021238
# GPA                      0.007272 -0.010184      -0.002187
# Semester_GPA             0.007264 -0.009947       0.001445
# CGPA                     0.006583 -0.010478       0.000506
# Dropout                  0.007434  0.007585      -0.010324
#
#                        Study_Hours_per_Day  Attendance_Rate  \
# Student_ID                       -0.004076         0.003646
# Age                               0.001677         0.011307
# ...

# %%
x=nd[["Family_Income"]]
y=nd["Dropout"]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test
# Out:
#       Family_Income
# 6252        29740.5
# 4684        29740.5
# 1731        29740.5
# 4742        29740.5
# 4521        29740.5
# ...             ...
# 6412        31279.0
# 8285        28214.0
# 7853        70261.0
# 1095        25000.0
# 6929        25000.0
#
# [2000 rows x 1 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pre=lr.predict(x_test)
y_pre
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(2000,))

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pre)
# Out:
# 0.7725

# %%
import matplotlib.pyplot as plt

plt.scatter(x,y)
plt.plot(x_test,y_pre,color="red")
plt.xlabel("Income")
plt.ylabel("Loan Status")
plt.show()
